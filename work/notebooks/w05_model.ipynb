# %% [markdown]
# # ML-08 — Capstone Modeling Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/hazemwalid100-hub/first-assignment/blob/main/work/notebooks/w05_model.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Method choice and why
#
# *Which method from the toolkit, and why it fits your lane.*
#
#
# 1.Method 1: Transparent rule baseline
# The final score and action codes are calculated using fixed thresholds and weighted rules.
#
#
# 2.Method 2: Signal analysis
# It analyzes signals such as:
#
# Traffic loss
# Position changes
# CTR gaps
# Impression surges
# 45-day performance windows
#
#
# I used these two methods because they are simple and suitable for this project. The rule-based method gives clear recommendations that are easy to understand. Signal analysis looks at different metrics, such as clicks, impressions, CTR, and search position, to find content that may need improvement.
#
# Using both methods makes the results easier to explain and helps identify different types of content problems.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Split design
#
# *Grouped by client? Time-aware? Say why this split is honest for your question.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Train + compare vs my baseline
#
# *Same data, same metric, same split as your Week-4 baseline. Show the table.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Errors and interpretation
#
# *Where is the model wrong? What does it lean on? A short error analysis beats a big metric table.*
#
#
#
# The model can be wrong because it mainly uses fixed rules instead of learning patterns from real data. For example, it assumes that a traffic drop of more than 20% means the content needs to be refreshed. However, the drop could have happened because of seasonality, competition, or a search engine update.
#
# The project also does not use a proper target variable or compare several trained ML models. Therefore, the results may look useful, but they do not prove that the recommendations are accurate. Overall, this project is more like a rule-based decision system than a real machine-learning model

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
