# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/hazemwalid100-hub/first-assignment/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*
#
#
# One row represents the performance of one page and keyword combination on one specific day. The dataset includes daily values such as clicks, impressions, CTR, average search position, page URL, keyword, and date.
#
# For the analysis, I group the daily rows by page and keyword. I then compare two consecutive 45-day windows: the previous 45 days and the most recent 45 days. Therefore, at least 90 days of data are needed for each page-keyword combination. The final score represents one page-keyword combination based on the changes between these two time periods.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*
#
#
# Features: clicks, impressions, CTR, and average position. These calculate traffic loss, position change, CTR gap, and impression growth.
#
# Label: The action flag, such as ACT_DECAY_REFRESH or ACT_CTR_OPTIMIZE. It is created by rules, so it is only a proxy.
#
# Context: Page URL, keyword, and date. They identify the page and organize the data into two 45-day periods.
#
# Excluded: I do not use the URL, keyword, or date directly as features because they are identifiers or organize the data. I also exclude the action flag from future features because it is the label.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*
#
#
# I checked the dataset to confirm the number of rows, the records for each page and keyword, the missing values, and the date range.
#
# I also checked the smallest number of records for each page and keyword. This confirmed whether there was enough data for the analysis. Since the project compares two 45-day periods, each page and keyword needs at least 90 days of data

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*
#
#
# This data cannot prove that one action will improve rankings or traffic. It only shows patterns in past performance.
#
# The data may also be unbalanced because some pages or page types may have more records than others. Early rows may contain only Google Search Console information, so some metrics may be missing or incomplete.
#
# The two time windows can also overlap with other reporting periods. Because of this, the results should be treated as useful recommendations, not guaranteed predictions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
