# %% [markdown]
# # ML-06 — Signal Audit: Do the Flags Hold?
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/hazemwalid100-hub/first-assignment/blob/main/work/notebooks/w04_signal_audit.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Distributions
#
# *Look before deciding: distributions of your key fields. Note the heavy tails.*
#
#
# I checked the main fields before creating the scoring rule. Clicks and impressions are not evenly distributed because some pages receive much more traffic than others. This creates heavy tails in these fields.
#
# CTR is mostly low, while average position is concentrated among the better-ranking pages. Because of these differences, I used averages and percentage changes between the two 45-day windows instead of relying only on raw values.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Signal test #1 / #2 / #3 (verdict each)
#
# *Three safe signals, each with a mini-test and a verdict: CONFIRMED / OPPOSITE / MIXED / FALSE.*
#
#
# Signal 1: Traffic loss and content refresh
# I compared clicks from the previous 45 days with clicks from the most recent 45 days. Pages with a large drop in clicks were more likely to receive the ACT_DECAY_REFRESH flag. Verdict: CONFIRMED.
#
# Signal 2: CTR and search position
# I compared the actual CTR with the expected CTR for the page’s search position. Pages with good positions but low CTR showed a stronger need for improvement. This supports the ACT_CTR_OPTIMIZE flag. Verdict: CONFIRMED.
#
# Signal 3: Impressions and clicks
# I compared the growth in impressions with the growth in clicks. Some pages received more impressions without receiving many more clicks. However, this pattern was not consistent for every page. Verdict: MIXED

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. The flag-linked test
#
# *Pick a signal one of FlyRank's real flags relies on. Does the data support the rule's assumption?*
#
#
# I tested the ACT_DECAY_REFRESH flag. The rule assumes that pages with more than 20% traffic loss between the two 45-day periods need a content refresh.
#
# I compared pages with traffic loss to pages with stable traffic. The pages with larger click decreases received higher decay scores and were more likely to get the ACT_DECAY_REFRESH flag. This supports the rule’s assumption.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. What this means in practice
#
# *Two or three sentences: what a content team should take from this.*
#
#
#
# The content team should review pages that lose a significant amount of traffic between the two 45-day periods. They should refresh those pages first, but the score should be treated as a recommendation and checked by a content manager before taking action

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
