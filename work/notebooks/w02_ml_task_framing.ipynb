# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/hazemwalid100-hub/first-assignment/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
#
#
# I chose scoring because the project gives each page a Content Opportunity Score from 0 to 100. It uses signals such as traffic loss, CTR, impressions, and search position to calculate the score.
#
# It also involves ranking because the pages are sorted from the highest priority to the lowest priority. This helps content managers and SEO strategists decide which pages should be updated first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
#
#
# I would predict the priority of each page and the action it should receive, such as refreshing the content, improving the CTR, expanding the content, or monitoring it.
#
# The label comes from a defined rule rather than a directly observed outcome. The project uses metrics like traffic loss, impressions, CTR, and search position, then applies thresholds to create the action label. Therefore, this label is a proxy for which pages may need attention, not proof that the recommendation will improve rankings or traffic.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
#
#
# I would use Precision@10. This measures how many of the top 10 pages selected by the system are actually judged by an SEO or content manager to need attention.
#
# A good result would be at least 80%, meaning that 8 out of the 10 highest-priority pages are useful recommendations. Since the current labels come from rules, this metric would need human review or future page performance data to properly evaluate whether the recommendations are correct

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*
#
#
# Unit of analysis: One row represents the performance of one page and keyword on one specific day.
#
# The dataset includes information such as clicks, impressions, CTR, average search position, page URL, keyword, and date. The project then groups the daily rows by page and keyword to compare two 45-day periods. The final scoring result represents one page-keyword combination and shows its opportunity score and recommended action.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
#
#
# A fixed rule only checks simple conditions, such as whether traffic dropped by 20%. However, content performance depends on many things, including clicks, impressions, CTR, and search position.
#
# ML could learn how these factors work together and make more flexible recommendations. This could help find pages that a simple rule might miss. However, ML would need enough reliable data and correct labels to work well

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
